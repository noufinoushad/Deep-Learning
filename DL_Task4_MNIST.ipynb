# %% [markdown]
# ### MLP for Multiclass Classification

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn import datasets

import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Load Dataset

# %%
#Load Dataset and extracting dataset

# Load the Fashion-MNIST dataset
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# ###Splitting data and Encoding

# %%
# Split the data into training and testing sets
x_train, x_test = x_train / 255.0, x_test / 255.0


x_train = x_train.reshape((x_train.shape[0], -1))
x_test = x_test.reshape((x_test.shape[0], -1))


# One-hot encode the labels
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# %% [markdown]
# ### Training the model

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(784,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))


model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])



# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.5157 - accuracy: 0.8145 - val_loss: 0.4027 - val_accuracy: 0.8540
# Epoch 2/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.3772 - accuracy: 0.8607 - val_loss: 0.3618 - val_accuracy: 0.8642
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3387 - accuracy: 0.8753 - val_loss: 0.3466 - val_accuracy: 0.8736
# Epoch 4/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.3142 - accuracy: 0.8831 - val_loss: 0.3635 - val_accuracy: 0.8641
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2975 - accuracy: 0.8891 - val_loss: 0.3272 - val_accuracy: 0.8828
# Epoch 6/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.2806 - accuracy: 0.8949 - val_loss: 0.3566 - val_accuracy: 0.8773
# Epoch 7/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2692 - accuracy: 0.8989 - val_loss: 0.3255 - val_accuracy: 0.8826
# Epoch 8/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2555 - accuracy: 0.9044 - val_loss: 0.3287 - val_accuracy: 0.8855
# Epoch 9/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2491 - accuracy: 0.9059 - val_loss: 0.3289 - val_accuracy: 0.8847
# Epoch 10/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.2397 - accuracy: 0.9094 - val_loss: 0.3383 - val_accuracy: 0.8832
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3656 - accuracy: 0.8733

# %% [markdown]
# ### Predicting

# %%
y_pred = mlp.predict(X_test)

# %% [markdown]
# ### Evaluating the model

# %%
# Evaluate the model
print(f"\nTest Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Test Loss: 0.3656
# Test Accuracy: 0.8733
